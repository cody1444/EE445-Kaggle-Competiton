# %% [markdown]
# The problem is predicting updrs_1, updrs_2, updrs_3 and updrs_4 values at a given visit_month and potential 6, 12 and 24 month visits after the current visit_month.
#
# Build models using linear regression, svm, logistic regression, random forests
#
# for lr, group 4 percentiles

# %%
import pandas as pd
import numpy as np

train_clinical = '~/School/EE445/kaggle/train_clinical_data.csv'
train_peptides = '~/School/EE445/kaggle/train_peptides.csv'
train_supp_clinical = '~/School/EE445/kaggle/supplemental_clinical_data.csv'
train_proteins = '~/School/EE445/kaggle/train_proteins.csv'

# %%
# load data
clinical_data = pd.read_csv(train_clinical)
protein_data = pd.read_csv(train_proteins)
peptide_data = pd.read_csv(train_peptides)
supp_data = pd.read_csv(train_supp_clinical)

# %% [markdown]
# ### Initialize DF:

# %%
def Get_ALL_Protein_Names(df_protein):
    return df_protein['UniProt'].unique().tolist()

def Get_Protein_Names(df_protein, visit_id):
    return protein_data.loc[protein_data['visit_id'] == visit_id]['UniProt'].tolist()

def Get_Patient_Info(df_clinical):
    return df_clinical.columns[0:3].tolist() + [df_clinical.columns[-1]]

def Get_Targets(df_clinical):
    return df_clinical.columns[3:7].tolist()

def Get_Protein_Visit_ID(df_protein):
    return df_protein['visit_id'].unique().tolist()

def Get_Clinical_Visit_ID(df_clinical):
    return df_clinical['visit_id'].tolist()

def Get_NPX(df_protein, visit_id):
    return df_protein.loc[df_protein['visit_id'] == visit_id]['NPX'].tolist()

def Create_Patient_Data_Dict(visit_id):
    pat_id, vis_mon = visit_id.split('_')
    return {'patient_id': int(pat_id), 'visit_month': int(vis_mon), 'visit_id': visit_id }

def Create_Protein_Data_Dict(df_protein, NPX_data, visit_id):
    return dict(zip(Get_Protein_Names(df_protein, visit_id), NPX_data)) | Create_Patient_Data_Dict(visit_id)
    
def Find_Visit_ID_Only_Protein_Measured(df_clinical, df_protein):
    protein_list = Get_Protein_Visit_ID(df_protein)
    clinical_list = Get_Clinical_Visit_ID(df_clinical)
    only_protein = [visit_id for visit_id in protein_list if visit_id not in clinical_list]
    return only_protein

def Find_Visit_ID_Only_UPDRS_Measured(df_clinical, df_protein):
    protein_list = Get_Protein_Visit_ID(df_protein)
    clinical_list = Get_Clinical_Visit_ID(df_clinical)
    only_UPDRS = [visit_id for visit_id in clinical_list if visit_id not in protein_list]
    return only_UPDRS

def Find_Visit_ID_Protein_and_UPDRS_Measured(df_clinical, df_protein):
    return [visit_id for visit_id in Get_Clinical_Visit_ID(df_clinical) if visit_id in Get_Protein_Visit_ID(df_protein)]

def Add_Rows_Only_Protein_Measured(df, only_prot_visit_id, df_protein):
    for visit_id in only_prot_visit_id:
        NPX_data = Get_NPX(df_protein, visit_id)
        protein_info = pd.DataFrame(Create_Protein_Data_Dict(df_protein, NPX_data, visit_id), index=[0])
        df = pd.concat([df, protein_info], axis = 0)
    return df

def Add_Protein_Data(df, df_clinical, df_protein):
    prot_visit_id = Find_Visit_ID_Protein_and_UPDRS_Measured(df_clinical, df_protein)
    for visit_id in prot_visit_id:
        NPX_data = Get_NPX(df_protein, visit_id)
        #protein_info = pd.DataFrame(Create_Protein_Data_Dict(df_protein, NPX_data, visit_id), index=[0])
        df.loc[df.index[df['visit_id']==visit_id], Get_Protein_Names(df_protein, visit_id)] = NPX_data
    return df

def Sort_and_Index(df):
    df = df.sort_values(by=['patient_id', 'visit_month'])
    df = df.reset_index()
    return df.drop(['index'], axis = 1)

def Create_Combined_DataFrame(df_clinical, df_protein):
    protein_cols = Get_ALL_Protein_Names(df_protein)
    patient_cols = Get_Patient_Info(df_clinical)
    target_cols = Get_Targets(df_clinical)
    df_with_UniProt_cols = pd.DataFrame(columns = protein_cols, index=df_clinical.index)
    clinical_left = df_clinical[patient_cols]
    clinical_right = df_clinical[target_cols]
    df = pd.concat([clinical_left, df_with_UniProt_cols, clinical_right], axis = 1)
    only_p = Find_Visit_ID_Only_Protein_Measured(clinical_data, protein_data)
    df = Add_Rows_Only_Protein_Measured(df, only_p, protein_data)
    df = Sort_and_Index(df)
    return Add_Protein_Data(df, df_clinical, df_protein)

# %%
df = Create_Combined_DataFrame(clinical_data, protein_data)

# %%
df
# Out:
#       visit_id  patient_id  visit_month upd23b_clinical_state_on_medication  \
# 0         55_0          55            0                                 NaN
# 1         55_3          55            3                                 NaN
# 2         55_6          55            6                                 NaN
# 3         55_9          55            9                                  On
# 4        55_12          55           12                                  On
# ...        ...         ...          ...                                 ...
# 2655  65043_48       65043           48                                 Off
# 2656  65043_54       65043           54                                 Off
# 2657  65043_60       65043           60                                 Off
# 2658  65043_72       65043           72                                 Off
# 2659  65043_84       65043           84                                 Off
#
#        O00391    O00533   O00584   O14498   O14773   O14791  ...   P32754  \
# 0     11254.3  732430.0  39585.8  41526.9  31238.0  4202.71  ...      NaN
# 1         NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 2     13163.6  630465.0  35220.8  41295.0  26219.9  4416.42  ...      NaN
# 3         NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 4     15257.6  815083.0  41650.9  39763.3  30703.6  4343.60  ...      NaN
# ...       ...       ...      ...      ...      ...      ...  ...      ...
# 2655  10589.6  902434.0  44890.8  38771.5  20188.3  3137.07  ...  57323.9
# 2656      NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 2657      NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 2658      NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 2659      NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
#
#        P60174   Q13449    Q99683   Q99829   Q9UKV8  updrs_1  updrs_2  updrs_3  \
# 0         NaN      NaN       NaN      NaN      NaN     10.0      6.0     15.0
# 1         NaN      NaN       NaN      NaN      NaN     10.0      7.0     25.0
# 2         NaN  49927.5  121417.0      NaN      NaN      8.0     10.0     34.0
# 3         NaN      NaN       NaN      NaN      NaN      8.0      9.0     30.0
# 4     20088.2  45519.2  121322.0  25589.4  65762.6     10.0     10.0     41.0
# ...       ...      ...       ...      ...      ...      ...      ...      ...
# 2655      NaN      NaN   96827.3  14019.1  39046.7      7.0      6.0     13.0
# 2656      NaN      NaN       NaN      NaN      NaN      4.0      8.0     11.0
# 2657      NaN      NaN       NaN      NaN      NaN      6.0      6.0     16.0
# 2658      NaN      NaN       NaN      NaN      NaN      3.0      9.0     14.0
# 2659      NaN      NaN       NaN      NaN      NaN      7.0      9.0     20.0
#
#       updrs_4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         0.0
# 4         0.0
# ...       ...
# 2655      0.0
# 2656      1.0
# 2657      1.0
# 2658      1.0
# 2659      3.0
#
# [2660 rows x 235 columns]

# %% [markdown]
# ### Validating The DF:

# %%
n = 100
results = []
for i in range(n):
    sample = protein_data.sample()
    p_id = sample['patient_id'].values[0]
    vm = sample['visit_month'].values[0]
    up = sample['UniProt'].values[0]
    npx = sample['NPX'].values[0]
    print('Check #:',i)
    print('Patient ID:', p_id)
    print('Visit Month:', vm)
    print('UniProt:', up)
    print('NPX from protein_data:', npx)
    result = float(df[up].loc[(df['patient_id'] == p_id)&(df['visit_month'] == vm)].values)
    print('NPX from df:', result)
    print('Pass?', result == npx)
    print('\n')
    if result == npx:
        results.append(True)
print('Percentage Correct:', sum(results)/n)
# Out:
# Check #: 0
# Patient ID: 5645
# Visit Month: 6
# UniProt: P02765
# NPX from protein_data: 2749940.0
# NPX from df: 2749940.0
# Pass? True
#
#
# Check #: 1
# Patient ID: 45161
# Visit Month: 48
# UniProt: P04075
# NPX from protein_data: 27936.8
# NPX from df: 27936.8
# Pass? True
#
#
# Check #: 2
# Patient ID: 13618
# Visit Month: 0
# UniProt: P00736
# NPX from protein_data: 28667.9
# NPX from df: 28667.9
# Pass? True
#
#
# Check #: 3
# Patient ID: 942
# Visit Month: 48
# UniProt: Q14508
# NPX from protein_data: 4887.67
# NPX from df: 4887.67
# Pass? True
#
#
# Check #: 4
# Patient ID: 20664
# Visit Month: 0
# UniProt: P01033
# NPX from protein_data: 64115.4
# NPX from df: 64115.4
# Pass? True
#
#
# Check #: 5
# Patient ID: 20707
# Visit Month: 36
# UniProt: P19823
# NPX from protein_data: 91017.5
# NPX from df: 91017.5
# Pass? True
#
#
# Check #: 6
# Patient ID: 47171
# Visit Month: 6
# UniProt: P01031
# NPX from protein_data: 9801.28
# NPX from df: 9801.28
# Pass? True
#
#
# Check #: 7
# Patient ID: 62792
# Visit Month: 0
# UniProt: P01011
# NPX from protein_data: 1627220.0
# NPX from df: 1627220.0
# Pass? True
#
#
# Check #: 8
# Patient ID: 26210
# Visit Month: 72
# UniProt: P16870
# NPX from protein_data: 164915.0
# NPX from df: 164915.0
# Pass? True
#
#
# Check #: 9
# Patient ID: 12516
# Visit Month: 36
# UniProt: Q9UKV8
# NPX from protein_data: 68921.2
# NPX from df: 68921.2
# Pass? True
#
#
# Check #: 10
# Patient ID: 8699
# Visit Month: 24
# UniProt: P01344
# NPX from protein_data: 72996.2
# NPX from df: 72996.2
# Pass? True
#
#
# Check #: 11
# Patient ID: 2660
# Visit Month: 6
# UniProt: P01833
# NPX from protein_data: 1851440.0
# NPX from df: 1851440.0
# Pass? True
#
#
# Check #: 12
# Patient ID: 18553
# Visit Month: 24
# UniProt: P98160
# NPX from protein_data: 2136.28
# NPX from df: 2136.28
# Pass? True
#
#
# Check #: 13
# Patient ID: 35465
# Visit Month: 0
# UniProt: P27169
# NPX from protein_data: 61873.2
# NPX from df: 61873.2
# Pass? True
#
#
# Check #: 14
# Patient ID: 52998
# Visit Month: 36
# UniProt: Q13449
# NPX from protein_data: 23216.0
# NPX from df: 23216.0
# Pass? True
#
#
# Check #: 15
# Patient ID: 5178
# Visit Month: 48
# UniProt: P07195
# NPX from protein_data: 8449.03
# NPX from df: 8449.03
# Pass? True
#
#
# Check #: 16
# Patient ID: 39719
# Visit Month: 36
# UniProt: P49908
# NPX from protein_data: 14088.8
# NPX from df: 14088.8
# Pass? True
#
#
# Check #: 17
# Patient ID: 48928
# Visit Month: 24
# UniProt: P02656
# NPX from protein_data: 162099.0
# NPX from df: 162099.0
# Pass? True
#
#
# Check #: 18
# Patient ID: 4161
# Visit Month: 36
# UniProt: Q14508
# NPX from protein_data: 9673.64
# NPX from df: 9673.64
# Pass? True
#
#
# Check #: 19
# Patient ID: 60443
# Visit Month: 0
# UniProt: Q02818
# NPX from protein_data: 11399.7
# NPX from df: 11399.7
# Pass? True
#
#
# Check #: 20
# Patient ID: 7886
# Visit Month: 12
# UniProt: O94919
# NPX from protein_data: 39449.9
# NPX from df: 39449.9
# Pass? True
#
#
# Check #: 21
# Patient ID: 5027
# Visit Month: 6
# UniProt: P19021
# NPX from protein_data: 9871.0
# NPX from df: 9871.0
# Pass? True
#
#
# Check #: 22
# Patient ID: 49239
# Visit Month: 12
# UniProt: P25311
# NPX from protein_data: 572023.0
# NPX from df: 572023.0
# Pass? True
#
#
# Check #: 23
# Patient ID: 64669
# Visit Month: 48
# UniProt: P10909
# NPX from protein_data: 7183540.0
# NPX from df: 7183540.0
# Pass? True
#
#
# Check #: 24
# Patient ID: 4172
# Visit Month: 48
# UniProt: Q8IWV7
# NPX from protein_data: 51842.9
# NPX from df: 51842.9
# Pass? True
#
#
# Check #: 25
# Patient ID: 44789
# Visit Month: 24
# UniProt: P01033
# NPX from protein_data: 84269.2
# NPX from df: 84269.2
# Pass? True
#
#
# Check #: 26
# Patient ID: 41444
# Visit Month: 48
# UniProt: P43251
# NPX from protein_data: 49489.9
# NPX from df: 49489.9
# Pass? True
#
#
# Check #: 27
# Patient ID: 14270
# Visit Month: 12
# UniProt: Q9HDC9
# NPX from protein_data: 336745.0
# NPX from df: 336745.0
# Pass? True
#
#
# Check #: 28
# Patient ID: 55302
# Visit Month: 48
# UniProt: P02679
# NPX from protein_data: 173338.0
# NPX from df: 173338.0
# Pass? True
#
#
# Check #: 29
# Patient ID: 16778
# Visit Month: 24
# UniProt: P02647
# NPX from protein_data: 7202440.0
# NPX from df: 7202440.0
# Pass? True
#
#
# Check #: 30
# Patient ID: 40798
# Visit Month: 12
# UniProt: P08294
# NPX from protein_data: 837772.0
# NPX from df: 837772.0
# Pass? True
#
#
# Check #: 31
# Patient ID: 30894
# Visit Month: 6
# UniProt: Q99832
# NPX from protein_data: 55660.6
# NPX from df: 55660.6
# Pass? True
#
#
# Check #: 32
# Patient ID: 49995
# Visit Month: 0
# UniProt: P08603
# NPX from protein_data: 1227180.0
# NPX from df: 1227180.0
# Pass? True
#
#
# Check #: 33
# Patient ID: 40650
# Visit Month: 48
# UniProt: P02753
# NPX from protein_data: 448356.0
# NPX from df: 448356.0
# Pass? True
#
#
# Check #: 34
# Patient ID: 12516
# Visit Month: 36
# UniProt: P02649
# NPX from protein_data: 14872300.0
# NPX from df: 14872300.0
# Pass? True
#
#
# Check #: 35
# Patient ID: 59550
# Visit Month: 48
# UniProt: P00441
# NPX from protein_data: 55527.1
# NPX from df: 55527.1
# Pass? True
#
#
# Check #: 36
# Patient ID: 55
# Visit Month: 0
# UniProt: P49588
# NPX from protein_data: 15043.9
# NPX from df: 15043.9
# Pass? True
#
#
# Check #: 37
# Patient ID: 40876
# Visit Month: 36
# UniProt: P98160
# NPX from protein_data: 2044.83
# NPX from df: 2044.83
# Pass? True
#
#
# Check #: 38
# Patient ID: 65043
# Visit Month: 24
# UniProt: P05452
# NPX from protein_data: 486244.0
# NPX from df: 486244.0
# Pass? True
#
#
# Check #: 39
# Patient ID: 62723
# Visit Month: 12
# UniProt: Q9UHG2
# NPX from protein_data: 206512.0
# NPX from df: 206512.0
# Pass? True
#
#
# Check #: 40
# Patient ID: 16574
# Visit Month: 0
# UniProt: Q13740
# NPX from protein_data: 23952.4
# NPX from df: 23952.4
# Pass? True
#
#
# Check #: 41
# Patient ID: 27872
# Visit Month: 36
# UniProt: P02452
# NPX from protein_data: 41298.4
# NPX from df: 41298.4
# Pass? True
#
#
# Check #: 42
# Patient ID: 60443
# Visit Month: 0
# UniProt: P00751
# NPX from protein_data: 540596.0
# NPX from df: 540596.0
# Pass? True
#
#
# Check #: 43
# Patient ID: 7886
# Visit Month: 12
# UniProt: Q8NE71
# NPX from protein_data: 10300.4
# NPX from df: 10300.4
# Pass? True
#
#
# Check #: 44
# Patient ID: 16566
# Visit Month: 0
# UniProt: P02753
# NPX from protein_data: 638957.0
# NPX from df: 638957.0
# Pass? True
#
#
# Check #: 45
# Patient ID: 60326
# Visit Month: 24
# UniProt: Q96PD5
# NPX from protein_data: 121813.0
# NPX from df: 121813.0
# Pass? True
#
#
# Check #: 46
# Patient ID: 45662
# Visit Month: 60
# UniProt: P01008
# NPX from protein_data: 3218740.0
# NPX from df: 3218740.0
# Pass? True
#
#
# Check #: 47
# Patient ID: 36797
# Visit Month: 6
# UniProt: P01009
# NPX from protein_data: 14589100.0
# NPX from df: 14589100.0
# Pass? True
#
#
# Check #: 48
# Patient ID: 27715
# Visit Month: 36
# UniProt: Q96BZ4
# NPX from protein_data: 8941.15
# NPX from df: 8941.15
# Pass? True
#
#
# Check #: 49
# Patient ID: 51243
# Visit Month: 12
# UniProt: P02655
# NPX from protein_data: 21016.5
# NPX from df: 21016.5
# Pass? True
#
#
# Check #: 50
# Patient ID: 15009
# Visit Month: 12
# UniProt: P13987
# NPX from protein_data: 461294.0
# NPX from df: 461294.0
# Pass? True
#
#
# Check #: 51
# Patient ID: 27607
# Visit Month: 48
# UniProt: Q8NBJ4
# NPX from protein_data: 31815.7
# NPX from df: 31815.7
# Pass? True
#
#
# Check #: 52
# Patient ID: 40751
# Visit Month: 0
# UniProt: P08697
# NPX from protein_data: 249783.0
# NPX from df: 249783.0
# Pass? True
#
#
# Check #: 53
# Patient ID: 62437
# Visit Month: 36
# UniProt: Q9HDC9
# NPX from protein_data: 221871.0
# NPX from df: 221871.0
# Pass? True
#
#
# Check #: 54
# Patient ID: 1923
# Visit Month: 0
# UniProt: P51884
# NPX from protein_data: 350707.0
# NPX from df: 350707.0
# Pass? True
#
#
# Check #: 55
# Patient ID: 16238
# Visit Month: 24
# UniProt: P02768
# NPX from protein_data: 367783000.0
# NPX from df: 367783000.0
# Pass? True
#
#
# Check #: 56
# Patient ID: 16778
# Visit Month: 6
# UniProt: P00450
# NPX from protein_data: 730669.0
# NPX from df: 730669.0
# Pass? True
#
#
# Check #: 57
# Patient ID: 29417
# Visit Month: 0
# UniProt: P10643
# NPX from protein_data: 52417.4
# NPX from df: 52417.4
# Pass? True
#
#
# Check #: 58
# Patient ID: 6211
# Visit Month: 60
# UniProt: Q562R1
# NPX from protein_data: 16811.9
# NPX from df: 16811.9
# Pass? True
#
#
# Check #: 59
# Patient ID: 7832
# Visit Month: 0
# UniProt: P02655
# NPX from protein_data: 24421.1
# NPX from df: 24421.1
# Pass? True
#
#
# Check #: 60
# Patient ID: 2660
# Visit Month: 0
# UniProt: P09871
# NPX from protein_data: 307501.0
# NPX from df: 307501.0
# Pass? True
#
#
# Check #: 61
# Patient ID: 39144
# Visit Month: 0
# UniProt: P55290
# NPX from protein_data: 30232.0
# NPX from df: 30232.0
# Pass? True
#
#
# Check #: 62
# Patient ID: 12516
# Visit Month: 48
# UniProt: P04004
# NPX from protein_data: 957840.0
# NPX from df: 957840.0
# Pass? True
#
#
# Check #: 63
# Patient ID: 25750
# Visit Month: 36
# UniProt: P00450
# NPX from protein_data: 808915.0
# NPX from df: 808915.0
# Pass? True
#
#
# Check #: 64
# Patient ID: 42003
# Visit Month: 0
# UniProt: Q14118
# NPX from protein_data: 68903.2
# NPX from df: 68903.2
# Pass? True
#
#
# Check #: 65
# Patient ID: 35675
# Visit Month: 0
# UniProt: P19823
# NPX from protein_data: 101892.0
# NPX from df: 101892.0
# Pass? True
#
#
# Check #: 66
# Patient ID: 27468
# Visit Month: 6
# UniProt: P00738
# NPX from protein_data: 4445170.0
# NPX from df: 4445170.0
# Pass? True
#
#
# Check #: 67
# Patient ID: 23244
# Visit Month: 36
# UniProt: P61769
# NPX from protein_data: 372906.0
# NPX from df: 372906.0
# Pass? True
#
#
# Check #: 68
# Patient ID: 25739
# Visit Month: 12
# UniProt: Q8N2S1
# NPX from protein_data: 6764.87
# NPX from df: 6764.87
# Pass? True
#
#
# Check #: 69
# Patient ID: 60788
# Visit Month: 48
# UniProt: Q8NBJ4
# NPX from protein_data: 17078.4
# NPX from df: 17078.4
# Pass? True
#
#
# Check #: 70
# Patient ID: 31270
# Visit Month: 12
# UniProt: Q8N2S1
# NPX from protein_data: 7115.4
# NPX from df: 7115.4
# Pass? True
#
#
# Check #: 71
# Patient ID: 7886
# Visit Month: 84
# UniProt: P10909
# NPX from protein_data: 4054600.0
# NPX from df: 4054600.0
# Pass? True
#
#
# Check #: 72
# Patient ID: 35231
# Visit Month: 48
# UniProt: O94919
# NPX from protein_data: 28499.3
# NPX from df: 28499.3
# Pass? True
#
#
# Check #: 73
# Patient ID: 44001
# Visit Month: 12
# UniProt: Q92520
# NPX from protein_data: 622125.0
# NPX from df: 622125.0
# Pass? True
#
#
# Check #: 74
# Patient ID: 36797
# Visit Month: 6
# UniProt: Q9UBX5
# NPX from protein_data: 22401.4
# NPX from df: 22401.4
# Pass? True
#
#
# Check #: 75
# Patient ID: 12703
# Visit Month: 36
# UniProt: Q02818
# NPX from protein_data: 19360.7
# NPX from df: 19360.7
# Pass? True
#
#
# Check #: 76
# Patient ID: 55662
# Visit Month: 0
# UniProt: P49908
# NPX from protein_data: 21185.4
# NPX from df: 21185.4
# Pass? True
#
#
# Check #: 77
# Patient ID: 24820
# Visit Month: 24
# UniProt: P06310
# NPX from protein_data: 12021.6
# NPX from df: 12021.6
# Pass? True
#
#
# Check #: 78
# Patient ID: 20581
# Visit Month: 24
# UniProt: O60888
# NPX from protein_data: 168014.0
# NPX from df: 168014.0
# Pass? True
#
#
# Check #: 79
# Patient ID: 61503
# Visit Month: 6
# UniProt: Q16610
# NPX from protein_data: 209773.0
# NPX from df: 209773.0
# Pass? True
#
#
# Check #: 80
# Patient ID: 55096
# Visit Month: 108
# UniProt: P12109
# NPX from protein_data: 54225.2
# NPX from df: 54225.2
# Pass? True
#
#
# Check #: 81
# Patient ID: 40022
# Visit Month: 48
# UniProt: P02760
# NPX from protein_data: 279765.0
# NPX from df: 279765.0
# Pass? True
#
#
# Check #: 82
# Patient ID: 49683
# Visit Month: 60
# UniProt: P25311
# NPX from protein_data: 934788.0
# NPX from df: 934788.0
# Pass? True
#
#
# Check #: 83
# Patient ID: 15245
# Visit Month: 48
# UniProt: P32754
# NPX from protein_data: 42528.9
# NPX from df: 42528.9
# Pass? True
#
#
# Check #: 84
# Patient ID: 51893
# Visit Month: 24
# UniProt: P01860
# NPX from protein_data: 429303.0
# NPX from df: 429303.0
# Pass? True
#
#
# Check #: 85
# Patient ID: 56691
# Visit Month: 12
# UniProt: P10451
# NPX from protein_data: 185997.0
# NPX from df: 185997.0
# Pass? True
#
#
# Check #: 86
# Patient ID: 40980
# Visit Month: 12
# UniProt: O75144
# NPX from protein_data: 80146.2
# NPX from df: 80146.2
# Pass? True
#
#
# Check #: 87
# Patient ID: 57009
# Visit Month: 36
# UniProt: P35542
# NPX from protein_data: 84543.9
# NPX from df: 84543.9
# Pass? True
#
#
# Check #: 88
# Patient ID: 34182
# Visit Month: 0
# UniProt: P05408
# NPX from protein_data: 5151.24
# NPX from df: 5151.24
# Pass? True
#
#
# Check #: 89
# Patient ID: 26809
# Visit Month: 48
# UniProt: O14498
# NPX from protein_data: 18739.4
# NPX from df: 18739.4
# Pass? True
#
#
# Check #: 90
# Patient ID: 58189
# Visit Month: 12
# UniProt: P16070
# NPX from protein_data: 94748.6
# NPX from df: 94748.6
# Pass? True
# Check #: 91
# Patient ID: 23391
# Visit Month: 60
# UniProt: P08697
# NPX from protein_data: 256764.0
# NPX from df: 256764.0
# Pass? True
#
#
# Check #: 92
# Patient ID: 5742
# Visit Month: 0
# UniProt: P16870
# NPX from protein_data: 84518.1
# NPX from df: 84518.1
# Pass? True
#
#
# Check #: 93
# Patient ID: 27468
# Visit Month: 60
# UniProt: P06310
# NPX from protein_data: 10181.2
# NPX from df: 10181.2
# Pass? True
#
#
# Check #: 94
# Patient ID: 10138
# Visit Month: 36
# UniProt: Q7Z3B1
# NPX from protein_data: 78972.2
# NPX from df: 78972.2
# Pass? True
#
#
# Check #: 95
# Patient ID: 20460
# Visit Month: 36
# UniProt: P98160
# NPX from protein_data: 1801.35
# NPX from df: 1801.35
# Pass? True
#
#
# Check #: 96
# Patient ID: 25827
# Visit Month: 12
# UniProt: Q06481
# NPX from protein_data: 27707.7
# NPX from df: 27707.7
# Pass? True
#
#
# Check #: 97
# Patient ID: 23175
# Visit Month: 3
# UniProt: P02452
# NPX from protein_data: 33077.5
# NPX from df: 33077.5
# Pass? True
#
#
# Check #: 98
# Patient ID: 49239
# Visit Month: 0
# UniProt: Q14118
# NPX from protein_data: 207055.0
# NPX from df: 207055.0
# Pass? True
#
#
# Check #: 99
# Patient ID: 56538
# Visit Month: 3
# UniProt: P04004
# NPX from protein_data: 1494630.0
# NPX from df: 1494630.0
# Pass? True
#
#
# Percentage Correct: 1.0

# %% [markdown]
# ### Create Model:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
target_cols = Get_Targets(clinical_data)
protein_cols = GeneratorExit(protein_data)
X = df.drop(target_cols, axis=1).loc[df['visit_month'] == 0]
y = df[target_cols].loc[df['visit_month'] == 0]
y = y.drop('updrs_4', axis=1)

# %%
X
# Out:
#      visit_id  patient_id  visit_month upd23b_clinical_state_on_medication  \
# 0        55_0          55            0                                 NaN
# 13      942_0         942            0                                 NaN
# 28     1517_0        1517            0                                  On
# 38     1923_0        1923            0                                 NaN
# 45     2660_0        2660            0                                 NaN
# ...       ...         ...          ...                                 ...
# 2595  63875_0       63875            0                                 NaN
# 2604  63889_0       63889            0                                 Off
# 2614  64669_0       64669            0                                 NaN
# 2629  64674_0       64674            0                                 NaN
# 2645  65043_0       65043            0                                 NaN
#
#        O00391    O00533   O00584   O14498   O14773   O14791  ...   Q9Y646  \
# 0     11254.3  732430.0  39585.8  41526.9  31238.0  4202.71  ...  23833.7
# 13        NaN       NaN      NaN      NaN      NaN      NaN  ...      NaN
# 28    11648.9  419015.0  35053.8      NaN  17466.3  2784.40  ...  19771.6
# 38    21361.8  866985.0  32035.1      NaN  13373.1      NaN  ...  26346.2
# 45        NaN  579829.0  28259.8  29883.2  19134.1  1884.61  ...  25630.0
# ...       ...       ...      ...      ...      ...      ...  ...      ...
# 2595  10216.7  562169.0  31586.1  22355.7  24650.4  2123.90  ...  18234.8
# 2604      NaN  409011.0  25629.1      NaN  14566.3      NaN  ...  13170.0
# 2614  10806.5  491365.0  26262.8  26712.7  15372.5  2995.08  ...      NaN
# 2629      NaN  351914.0  21625.1  17712.4  20849.8      NaN  ...  22257.6
# 2645  13472.4  927954.0  42661.5  43663.2  20071.3  3278.88  ...  28346.5
#
#        Q9Y6R7    P01594   P02792    P32754    P60174   Q13449    Q99683  \
# 0     18953.5       NaN      NaN       NaN       NaN      NaN       NaN
# 13        NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 28    14699.5  18356.40  25826.9  124675.0  18494.30  32892.8   90539.1
# 38    23597.1       NaN  27842.6   75856.4  12385.70  22141.7   93929.3
# 45    17990.9  10813.80      NaN  103346.0  14354.80  29919.2   86771.8
# ...       ...       ...      ...       ...       ...      ...       ...
# 2595  22909.1  12991.90  12190.2  108133.0  15677.80  28445.1       NaN
# 2604      NaN       NaN   8943.7       NaN   6414.41  26380.4   82380.5
# 2614  25094.2  11587.50  14343.7       NaN       NaN  30778.7  109909.0
# 2629  10510.5   6551.39  13407.9       NaN       NaN      NaN   98204.8
# 2645  35617.5       NaN      NaN       NaN       NaN  57483.7  100907.0
#
#        Q99829   Q9UKV8
# 0         NaN      NaN
# 13        NaN      NaN
# 28    11373.4  55379.8
# 38    12141.1  64302.3
# 45        NaN  55047.2
# ...       ...      ...
# 2595  14416.9  85051.3
# 2604      NaN  82577.7
# 2614  15110.2  63783.2
# 2629      NaN  64857.7
# 2645      NaN  37584.6
#
# [248 rows x 231 columns]

# %%
y
# Out:
#       updrs_1  updrs_2  updrs_3
# 0        10.0      6.0     15.0
# 13        3.0      2.0     20.0
# 28       11.0      6.0     25.0
# 38        2.0      0.0      0.0
# 45        2.0      0.0      0.0
# ...       ...      ...      ...
# 2595      3.0      2.0      4.0
# 2604      7.0      3.0     30.0
# 2614     12.0     14.0     27.0
# 2629      5.0      1.0     13.0
# 2645      2.0      6.0     16.0
#
# [248 rows x 3 columns]

# %%
y.isna().sum()
# Out:
# updrs_1    0
# updrs_2    0
# updrs_3    0
# dtype: int64

# %%
# Split data into training & testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Define transforms on numeric types
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])

# Define transforms on categorical types
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Construct ColumnTransformer object for X
preprocessor_X = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, protein_cols + ['visit_month']),
        ('cat', categorical_transformer, [patient_info_cols[2]])
    ],
    remainder='passthrough',
    verbose=True,
    verbose_feature_names_out=True)

# Construct ColumnTransformer object for y
preprocessor_y = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, [target_cols[-1]]),
    ],
    remainder='passthrough',
    verbose=True,
    verbose_feature_names_out=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23808/3766761545.py in <module>
#      11 preprocessor_X = ColumnTransformer(
#      12     transformers=[
# ---> 13         ('num', numeric_transformer, protein_cols + ['visit_month']),
#      14         ('cat', categorical_transformer, [patient_info_cols[2]])
#      15     ],
#
# TypeError: unsupported operand type(s) for +: 'GeneratorExit' and 'list'

# %%
# Drop rows containing NaN
y_train_sparse = y_train.dropna()
X_train_sparse = X_train.loc[y_train_sparse.index]

y_test_sparse = y_test.dropna()
X_test_sparse = X_test.loc[y_test_sparse.index]

# Train the model
model = LinearRegression(fit_intercept=False).fit(preprocessor_X.fit_transform(X_train_sparse),
                                                  preprocessor_y.fit_transform(y_train_sparse))

# %%
y_pred = model.predict(preprocessor_X.fit_transform(X_test_sparse))

# %%
model.score(preprocessor_X.fit_transform(X_test_sparse), preprocessor_y.fit_transform(y_test_sparse))
